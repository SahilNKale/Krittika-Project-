# %%
from scipy.integrate import odeint
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
# %matplotlib notebook

# %% [markdown]
# ## Krttika Assignment 2
# ### Solving the given system of equations for three body problem with `Euler-Richarson` method

# %%
mu1=7.19 * (10**-4)
x0_0=-1
x1_0=0
x2_0=0
x3_0=0
S_0L3=(x0_0,x1_0,x2_0,x3_0)
S_0L4=(0.5-mu1,0,0.865,0)
S_0L5=(0.5-mu1,0,-0.865,0)
S_0L1=(0.5,0,0,0)
S_0L2=(1.1,0,0,0)
x1,y1,x2,y2=-mu1,0,1-mu1,0


def acx(x0,x2,x3,mu):
    return 2*x3 + x0 -(((1- mu)*(x0 + mu))/(np.sqrt( (x0+ mu)**2 + (x2)**2))**3) - ((mu*(x0-1+mu))/(np.sqrt( ( x0 - 1 +mu)**2 + (x2)**2))**3)

def acy(x0,x1,x2,mu):
    return -2*x1 + x2 - ((1-mu)*x2/(np.sqrt( (x0+ mu)**2 + (x2)**2))**3) - ((mu*x2)/(np.sqrt( ( x0 - 1 +mu)**2 + (x2)**2)**3))


def EulerRichardson1(S,h,i,ts,mu):
    Vex=[]
    X=[]
    Vey=[]
    Y=[]
    Xmid=[]
    Ymid=[]
    Vexmid=[]
    acxmid=[]
    Veymid=[]
    acymid=[]
    acx1=[]
    acy1=[]
    
    t=np.linspace(0,ts,i)
    for j in range(i):
        if(j==0):
            acx1.append(acx(S[0],S[2],S[3],mu))
            acy1.append(acy(S[0],S[1],S[2],mu))
            X.append(S[0])
            Y.append(S[2])
            Vex.append(S[1])
            Vey.append(S[3])
            Xmid.append(S[0] + Vex[0]*h*0.5)
            Ymid.append(S[2] + Vey[0]*h*0.5)
            Vexmid.append(Vex[0] + acx1[0]*h*0.5)
            Veymid.append(Vey[0] + acy1[0]*h*0.5)
            acxmid.append(acx(Xmid[0],Ymid[0],Veymid[0],mu))
            acymid.append(acy(Xmid[0],Vexmid[0],Ymid[0],mu))
        else:
            X.append(X[j-1] + Vexmid[j-1]*h)
            Y.append(Y[j-1] + Veymid[j-1]*h)
            Vex.append(Vex[j-1] + acxmid[j-1]*h)
            Vey.append(Vey[j-1] + acymid[j-1]*h)
            Xmid.append(X[j] + Vex[j]*h*0.5)
            Ymid.append(Y[j] + Vey[j]*h*0.5)
            acx1.append(acx(X[j],Y[j],Vey[j],mu))
            acy1.append(acy(X[j],Vex[j],Y[j],mu))
            Vexmid.append(Vex[j] + acx1[j]*h*0.5)
            Veymid.append(Vey[j] + acy1[j]*h*0.5)
            acxmid.append(acx(Xmid[j],Ymid[j],Veymid[j],mu))
            acymid.append(acy(Xmid[j],Vexmid[j],Ymid[j],mu))
            
    return X,Y

# %% [markdown]
# #### Plot and Animation for the trajectory of the smaller mass for perturbtion from point `L4`

# %%
XL4,YL4=EulerRichardson1(S_0L4,0.01,80000,1000,mu1)

# %%
plt.plot(XL4[0::10],YL4[0::10])
plt.plot(0.5-mu1,0.865,marker='o',markersize=10,markeredgecolor='red',markerfacecolor='orange')
plt.title(['Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(7.41x(10^11)m)')
plt.ylabel('Y-Cordinate')
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">
# Text(0, 0.5, 'Y-Cordinate')

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0.42,0.57), ylim=(0.82,0.92))
line, = ax.plot([], [],lw=2)

def init():
    line.set_data([], [])
    return line,
x=[]
y=[]
def animate(i):
    x.append(XL4[75*i])
    y.append(YL4[75*i])
    line.set_data(x, y)
    line.set_markersize(ms)
    return line,

anim = animation.FuncAnimation(fig, animate,init_func=init,
                               frames=600, interval=5, blit=True)
plt.title(['Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(7.41x(10^11)m)')
plt.ylabel('Y-Cordinate')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">

# %% [markdown]
# #### Plot and Animation for the trajectory of the smaller mass for perturbtion from point `L3`

# %%
XL3,YL3=EulerRichardson1(S_0L3,0.01,50000,5000,mu1)
plt.plot(XL3[0::45],YL3[0::45])
plt.plot(x1,y1,marker='o',markersize=10,markeredgecolor='red',markerfacecolor='orange')
plt.plot(x2,y2,marker='o',markersize=6,markerfacecolor='brown',markeredgecolor='black')
plt.title(['Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(7.41x(10^11)m)')
plt.ylabel('Y-Cordinate')
plt.text(mu1-0.05,-0.13,'Sun',fontsize=10)
plt.text(1-mu1-0.05,-0.13,'Jupiter',fontsize=10)
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">
# (-1.5, 1.5)

# %%
fig = plt.figure()
ax = plt.axes(xlim=(-1.5,1.5), ylim=(-1.5, 1.5))
line, = ax.plot([], [],lw=2)

def init():
    line.set_data([], [])
    return line,
x=[]
y=[]
def animate(i):
    x.append(XL3[80*i])
    y.append(YL3[80*i])
    line.set_data(x, y)
    line.set_markersize(ms) 
    return line,

anim = animation.FuncAnimation(fig, animate,init_func=init,
                               frames=550, interval=10, blit=True)



plt.plot(x1,y1,marker='o',markersize=10,markeredgecolor='red',markerfacecolor='orange')
plt.plot(x2,y2,marker='o',markersize=6,markerfacecolor='brown',markeredgecolor='black')
plt.title(['Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(7.41x(10^11)m)')
plt.ylabel('Y-Cordinate')
plt.text(mu1-0.05,-0.13,'Sun',fontsize=10)
plt.text(1-mu1-0.05,-0.13,'Jupiter',fontsize=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">

# %% [markdown]
# #### Plot and Animation for the trajectory of the smaller mass for perturbtion from point `L5`

# %%
XL5,YL5=EulerRichardson1(S_0L5,0.01,80000,1000,mu1)
plt.plot(XL5[0::10],YL5[0::10])
plt.plot(0.5-mu1,-0.865,marker='o',markersize=10,markeredgecolor='red',markerfacecolor='orange')
plt.title(['Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(7.41x(10^11)m)')
plt.ylabel('Y-Cordinate')
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">
# Text(0, 0.5, 'Y-Cordinate')

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0.42,0.57), ylim=(-0.92,-0.82))
line, = ax.plot([], [],lw=2)

def init():
    line.set_data([], [])
    return line,
x=[]
y=[]
def animate(i):
    x.append(XL5[75*i])
    y.append(YL5[75*i])
    line.set_data(x, y)
    line.set_markersize(ms)
    return line,

anim = animation.FuncAnimation(fig, animate,init_func=init,
                               frames=600, interval=5, blit=True)
plt.title([
    
    
    
    'Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(7.41x(10^11)m)')
plt.ylabel('Y-Cordinate')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">

# %% [markdown]
# ### For small values of mu system becomes very chaotic as stability of the lagrenge points depletes
# #### Example:` Earth Moon system`

# %%
mu2=0.012
S_0ME=(0.5-mu2,0,0.865,0)
Xm,Ym=EulerRichardson1(S_0ME,0.01,80000,1000,mu2)
plt.plot(Xm[0::10],Ym[0::10])
plt.plot(0.5-mu2,0.865,marker='o',markersize=10,markerfacecolor='Black')
plt.title(['Three Body Problem in Rotating Frame'])
plt.legend(['Trajectory'])
plt.xlabel('X-Cordinate(3.84x(10^7)m)')
plt.ylabel('Y-Cordinate')
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">
# Text(0, 0.5, 'Y-Cordinate')

# %% [markdown]
# ##   Zero Velocity Curve

# %%
def zerovelocity(x,y,mu):
    p1=np.sqrt((x+mu)**2 + y**2)
    p2=np.sqrt((x-1 + mu)**2 + y**2)
    return x**2 + y**2 + (2*(1-mu)/p1) + 2*mu/p2

# %%
x=np.linspace(-1.5,1.5)
y=np.linspace(-1.5,1.5)
X,Y=np.meshgrid(x,y)
Z=zerovelocity(X,Y,0.1)
plt.contourf(X,Y,Z,levels=[2,2.25,2.45,2.5,2.52,2.6,2.8,2.85,2.88,2.9,3,3.01,3.05,3.08,3.10,3.1025,3.5,3.6,4])
plt.colorbar();
plt.contour(X,Y,Z,levels=[2,2.25,2.5,2.8,3.102,3.5,4])
plt.plot(0.5-mu1,0.865,marker='o',markersize=5,markerfacecolor='black')
plt.plot(0.5-mu1,-0.865,marker='o',markersize=5,markerfacecolor='black')
plt.plot(-1-mu1,0,marker='o',markersize=5,markerfacecolor='black')
plt.plot(x1,y1,marker='o',markersize=10,markeredgecolor='red',markerfacecolor='orange')
plt.plot(x2,y2,marker='o',markersize=6,markerfacecolor='brown',markeredgecolor='black')
plt.title('Zero Velocity Curves')
# Out:
# <img src="data:image/png;base64,..." width="856.0224059145972">
# Text(0.5, 1.0, 'Zero Velocity Curves')
